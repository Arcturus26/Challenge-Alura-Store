# %% [markdown]
# <a href="https://colab.research.google.com/github/Arcturus26/Challenge-Alura-Store/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
dataframes = [tienda, tienda2, tienda3, tienda4]
for i, dataframe in enumerate(dataframes, start=1):
    dataframe['Tienda'] = f'Tienda {i}'

tiendas_combinadas = pd.concat([tienda, tienda2, tienda3, tienda4])
tiendas_combinadas
# Out:
#                 Producto   Categoría del Producto    Precio  Costo de envío  \
# 0      Asistente virtual             Electrónicos  164300.0          6900.0
# 1        Mesa de comedor                  Muebles  192300.0          8400.0
# 2          Juego de mesa                 Juguetes  209600.0         15900.0
# 3             Microondas        Electrodomésticos  757500.0         41000.0
# 4       Silla de oficina                  Muebles  335200.0         20200.0
# ...                  ...                      ...       ...             ...
# 2353     Mesa de comedor                  Muebles  227700.0         12600.0
# 2354    Silla de oficina                  Muebles  342000.0         18600.0
# 2355        Vaso térmico     Deportes y diversión   36700.0          2400.0
# 2356        Set de ollas  Artículos para el hogar  151800.0          8300.0
# 2357  Cuerda para saltar     Deportes y diversión   11200.0          1300.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0         16/01/2021      Pedro Gomez          Bogotá             4
# 1         18/05/2022  Beatriz Morales        Medellín             1
# 2         15/03/2021   Juan Fernandez       Cartagena             1
# 3         03/05/2022   Juan Fernandez            Cali             4
# 4         07/11/2020    Maria Alfonso        Medellín             5
# ...              ...              ...             ...           ...
# 2353      12/02/2020    Camila Rivera        Medellín             5
# 2354      17/05/2022    Felipe Santos     Bucaramanga             5
# 2355      03/05/2022    Camila Rivera          Bogotá             5
# 2356      15/06/2020   Blanca Ramirez            Cali             5
# 2357      17/11/2021    Felipe Santos          Bogotá             5
#
#           Método de pago  Cantidad de cuotas       lat       lon    Tienda
# 0     Tarjeta de crédito                   8   4.60971 -74.08175  Tienda 1
# 1     Tarjeta de crédito                   4   6.25184 -75.56359  Tienda 1
# 2     Tarjeta de crédito                   1  10.39972 -75.51444  Tienda 1
# 3                  Nequi                   1   3.43722 -76.52250  Tienda 1
# 4                  Nequi                   1   6.25184 -75.56359  Tienda 1
# ...                  ...                 ...       ...       ...       ...
# 2353  Tarjeta de crédito                   1   6.25184 -75.56359  Tienda 4
# 2354  Tarjeta de crédito                   3   7.12539 -73.11980  Tienda 4
# 2355  Tarjeta de crédito                   1   4.60971 -74.08175  Tienda 4
# 2356  Tarjeta de crédito                   1   3.43722 -76.52250  Tienda 4
# 2357  Tarjeta de crédito                   1   4.60971 -74.08175  Tienda 4
#
# [9435 rows x 13 columns]

# %%
# tiendas_combinadas.groupby('Tienda')['Precio'].sum().map('{:,.2f}'.format)
facturacion = (
    tiendas_combinadas
    .groupby('Tienda')['Precio']
    .sum()
    .apply(lambda x: f"$ {x:,.2f}")
    .to_frame(name='Facturacion')
    )
facturacion
# Out:
#                  Facturacion
# Tienda
# Tienda 1  $ 1,150,880,400.00
# Tienda 2  $ 1,116,343,500.00
# Tienda 3  $ 1,098,019,600.00
# Tienda 4  $ 1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
ventas_por_categoria = (
    tiendas_combinadas.pivot_table(
      index='Categoría del Producto',
      columns='Tienda',
      aggfunc='size')
    )
ventas_por_categoria
# Out:
# Tienda                   Tienda 1  Tienda 2  Tienda 3  Tienda 4
# Categoría del Producto
# Artículos para el hogar       171       181       177       201
# Deportes y diversión          284       275       277       277
# Electrodomésticos             312       305       278       254
# Electrónicos                  448       422       451       451
# Instrumentos musicales        182       224       177       170
# Juguetes                      324       313       315       338
# Libros                        173       197       185       187
# Muebles                       465       442       499       480

# %%
categorias_mas_populares = (
    ventas_por_categoria
    .idxmax(axis=0)
    .to_frame(name='Categoría más popular')
    )
categorias_mas_populares
# Out:
#          Categoría más popular
# Tienda
# Tienda 1               Muebles
# Tienda 2               Muebles
# Tienda 3               Muebles
# Tienda 4               Muebles

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
calificaciones_promedio = (
    tiendas_combinadas
    .groupby('Tienda')['Calificación']
    .mean()
    .to_frame(name='Calificación promedio')
    .round(2)
    )
calificaciones_promedio
# Out:
#           Calificación promedio
# Tienda
# Tienda 1                   3.98
# Tienda 2                   4.04
# Tienda 3                   4.05
# Tienda 4                   4.00

# %%
# Ademas si quisieramos en detalle las calificaciones promedio:
tiendas_combinadas.pivot_table(index='Categoría del Producto', columns='Tienda', values='Calificación', aggfunc='mean', margins=True, margins_name='Promedio Total').round(2)
# Out:
# Tienda                   Tienda 1  Tienda 2  Tienda 3  Tienda 4  \
# Categoría del Producto
# Artículos para el hogar      3.75      4.07      4.07      4.01
# Deportes y diversión         3.90      4.07      3.94      4.05
# Electrodomésticos            4.03      4.07      4.01      3.93
# Electrónicos                 4.00      3.97      3.99      4.01
# Instrumentos musicales       4.05      4.04      4.01      3.91
# Juguetes                     4.08      4.03      4.20      3.99
# Libros                       3.98      3.95      4.05      4.04
# Muebles                      3.95      4.09      4.10      4.00
# Promedio Total               3.98      4.04      4.05      4.00
#
# Tienda                   Promedio Total
# Categoría del Producto
# Artículos para el hogar            3.98
# Deportes y diversión               3.99
# Electrodomésticos                  4.01
# Electrónicos                       3.99
# Instrumentos musicales             4.00
# Juguetes                           4.07
# Libros                             4.00
# Muebles                            4.03
# Promedio Total                     4.01

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
filtros = [
    (
        df.groupby('Producto')
        .size()
        .reset_index(name='Ventas')
        .sort_values('Ventas', ascending=False)
        .reset_index(drop=True)
        .set_axis(
            pd.MultiIndex.from_tuples([
                (f'Tienda {i}', 'Producto'),
                (f'Tienda {i}', 'Ventas')
            ]),
            axis=1)
    )
    for i, df in enumerate(dataframes, start=1)
]

ventas_totales = pd.concat(filtros, axis=1)
ventas_totales
# Out:
#                        Tienda 1                            Tienda 2         \
#                        Producto Ventas                     Producto Ventas
# 0                       Armario     60    Iniciando en programación     65
# 1                 TV LED UHD 4K     60                   Microondas     62
# 2                    Microondas     60                      Batería     61
# 3              Secadora de ropa     58                    Pandereta     58
# 4                 Mesa de noche     56            Guitarra acústica     58
# 5       Bloques de construcción     56             Secadora de ropa     57
# 6           Balón de baloncesto     55                    Iphone 15     55
# 7                     Bicicleta     54      Bloques de construcción     54
# 8                     Impresora     54                      Armario     54
# 9                  Vaso térmico     54                 Set de ollas     52
# 10                 Refrigerador     54           Cuerda para saltar     50
# 11                      Batería     53             Lavadora de ropa     49
# 12                   Cubertería     52                 Refrigerador     49
# 13    Carrito de control remoto     52             Silla de oficina     49
# 14          Modelado predictivo     51                  Muñeca bebé     48
# 15                  Auriculares     50                 Vaso térmico     47
# 16            Ajedrez de madera     49                     Cama box     47
# 17                    Iphone 15     49    Carrito de control remoto     47
# 18                 Lavavajillas     48           Guitarra eléctrica     47
# 19           Guitarra eléctrica     47            Balón de voleibol     46
# 20             Lavadora de ropa     47          Modelado predictivo     46
# 21             Silla de oficina     46                 Lavavajillas     46
# 22              Sofá reclinable     46                 Set de vasos     46
# 23            Guitarra acústica     46                Kit de bancas     45
# 24                       Estufa     45                TV LED UHD 4K     45
# 25               Mesa de centro     44                      Mochila     45
# 26                Kit de bancas     44               Mesa de centro     45
# 27                     Cama box     44              Cubo mágico 8x8     45
# 28              Cubo mágico 8x8     44                    Bicicleta     45
# 29                     Smart TV     44            Ajedrez de madera     45
# 30                    Cama king     44                    Cama king     45
# 31                Juego de mesa     43              Sofá reclinable     44
# 32                   Smartwatch     43                Mesa de noche     44
# 33                 Set de ollas     43              Olla de presión     44
# 34      Dashboards con Power BI     42    Auriculares con micrófono     44
# 35                  Tablet ABXY     42                  Tablet ABXY     44
# 36            Balón de voleibol     42                   Smartwatch     44
# 37                       Sillón     41      Dashboards con Power BI     43
# 38    Iniciando en programación     41  Ciencia de datos con Python     43
# 39                 Set de vasos     41          Balón de baloncesto     42
# 40            Asistente virtual     40               Dinosaurio Rex     42
# 41               Dinosaurio Rex     40                       Estufa     42
# 42           Cuerda para saltar     40                 Celular ABXY     41
# 43                  Muñeca bebé     40                     Smart TV     40
# 44              Mesa de comedor     40                   Cubertería     39
# 45  Ciencia de datos con Python     39            Asistente virtual     38
# 46                      Mochila     39                  Auriculares     37
# 47                    Pandereta     36                       Sillón     35
# 48              Olla de presión     35                    Impresora     34
# 49                 Celular ABXY     33              Mesa de comedor     34
# 50    Auriculares con micrófono     33                Juego de mesa     32
#
#                        Tienda 3                            Tienda 4
#                        Producto Ventas                     Producto Ventas
# 0                 Kit de bancas     57                     Cama box     62
# 1               Mesa de comedor     56                   Cubertería     59
# 2                     Cama king     56                    Cama king     56
# 3                  Set de ollas     55      Dashboards con Power BI     56
# 4                 Mesa de noche     55    Carrito de control remoto     55
# 5                      Smart TV     54                Mesa de noche     55
# 6           Modelado predictivo     53              Mesa de comedor     55
# 7            Cuerda para saltar     53      Bloques de construcción     54
# 8                        Estufa     53                     Smart TV     54
# 9     Carrito de control remoto     52                    Pandereta     52
# 10                Juego de mesa     52            Asistente virtual     50
# 11                 Lavavajillas     52          Balón de baloncesto     50
# 12                    Bicicleta     52                    Impresora     50
# 13                    Pandereta     51                 Set de ollas     50
# 14          Balón de baloncesto     50          Modelado predictivo     50
# 15                 Refrigerador     50                    Iphone 15     48
# 16                    Impresora     50            Balón de voleibol     48
# 17                      Armario     49                      Batería     48
# 18            Balón de voleibol     48                Juego de mesa     48
# 19                  Tablet ABXY     48                  Muñeca bebé     48
# 20              Olla de presión     47                   Microondas     48
# 21                       Sillón     47                 Vaso térmico     48
# 22            Ajedrez de madera     47              Cubo mágico 8x8     47
# 23            Guitarra acústica     47                       Estufa     47
# 24                   Smartwatch     46              Sofá reclinable     47
# 25                    Iphone 15     46               Dinosaurio Rex     47
# 26             Silla de oficina     46              Olla de presión     46
# 27    Iniciando en programación     46                 Set de vasos     46
# 28                     Cama box     46                       Sillón     45
# 29  Ciencia de datos con Python     46                  Tablet ABXY     45
# 30               Dinosaurio Rex     46                    Bicicleta     45
# 31              Sofá reclinable     45                  Auriculares     44
# 32             Secadora de ropa     45               Mesa de centro     44
# 33                 Celular ABXY     44                      Mochila     43
# 34              Cubo mágico 8x8     44           Cuerda para saltar     43
# 35                  Auriculares     43                 Lavavajillas     43
# 36             Lavadora de ropa     42    Iniciando en programación     43
# 37                TV LED UHD 4K     42    Auriculares con micrófono     42
# 38               Mesa de centro     42                Kit de bancas     42
# 39                      Batería     41                TV LED UHD 4K     40
# 40      Dashboards con Power BI     40             Silla de oficina     40
# 41    Auriculares con micrófono     39             Secadora de ropa     40
# 42            Asistente virtual     39                 Celular ABXY     39
# 43                  Muñeca bebé     39            Ajedrez de madera     39
# 44                   Cubertería     39                   Smartwatch     39
# 45                 Vaso térmico     38             Lavadora de ropa     38
# 46           Guitarra eléctrica     38  Ciencia de datos con Python     38
# 47                      Mochila     36                 Refrigerador     38
# 48                   Microondas     36            Guitarra acústica     37
# 49                 Set de vasos     36                      Armario     34
# 50      Bloques de construcción     35           Guitarra eléctrica     33

# %%
ventas_totales.head()
# Out:
#            Tienda 1                          Tienda 2                Tienda 3  \
#            Producto Ventas                   Producto Ventas         Producto
# 0           Armario     60  Iniciando en programación     65    Kit de bancas
# 1     TV LED UHD 4K     60                 Microondas     62  Mesa de comedor
# 2        Microondas     60                    Batería     61        Cama king
# 3  Secadora de ropa     58                  Pandereta     58     Set de ollas
# 4     Mesa de noche     56          Guitarra acústica     58    Mesa de noche
#
#                            Tienda 4
#   Ventas                   Producto Ventas
# 0     57                   Cama box     62
# 1     56                 Cubertería     59
# 2     56                  Cama king     56
# 3     55    Dashboards con Power BI     56
# 4     55  Carrito de control remoto     55

# %%
ventas_totales.tail()
# Out:
#                      Tienda 1                Tienda 2         \
#                      Producto Ventas         Producto Ventas
# 46                    Mochila     39      Auriculares     37
# 47                  Pandereta     36           Sillón     35
# 48            Olla de presión     35        Impresora     34
# 49               Celular ABXY     33  Mesa de comedor     34
# 50  Auriculares con micrófono     33    Juego de mesa     32
#
#                    Tienda 3                            Tienda 4
#                    Producto Ventas                     Producto Ventas
# 46       Guitarra eléctrica     38  Ciencia de datos con Python     38
# 47                  Mochila     36                 Refrigerador     38
# 48               Microondas     36            Guitarra acústica     37
# 49             Set de vasos     36                      Armario     34
# 50  Bloques de construcción     35           Guitarra eléctrica     33

# %% [markdown]
# # 5. Envío promedio por tienda
